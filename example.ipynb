# %% [markdown]
# ## Import the template

# %%
import pe_sample

# DEBUG:
import importlib
pe_sample = importlib.reload(pe_sample)

# %% [markdown]
# ## Configure the scan

# %%
from secret import VIRUSTOTAL_API_KEY

cfg = pe_sample.ScanConfig

cfg.virustotal_api_key = VIRUSTOTAL_API_KEY
cfg.procmon_vm = 'Windows10 VM'

# %% [markdown]
# ## Scan all samples in a folder

# %%
from os import path, listdir

for sample in listdir('samples'):
    pe_sample.scan(path.join('samples', sample), cfg)
# Out:
# <h1>Report for c522418670b4efa6c754ea19bf18e60d31e8c17929038cd3f14317134230a6e6:</h1>
# <h3>Checksums:</h3>
# <p><ul><li><b>md5</b> - 2337089f5225107923bd963581f8ab1e</li><li><b>sha1</b> - d5f7424aa37744000c386320abe111efcfca461e</li><li><b>sha256</b> - c522418670b4efa6c754ea19bf18e60d31e8c17929038cd3f14317134230a6e6</li><li><b>imphash</b> - e72731bca9642384c84ef52bd617a1ab</li><li><b>spamsum</b> - 1536:W4vY7pfE9e7alnnBrXkZPk19OihKI1MxURrMBNWCWwwLww5wwKwwzwwdwwzwwFwW:L5ogxskt11QBNWC</li><li><b>tlsh</b> - T172F3093E39650C26F1D746305E9474009AC8CF840F937ECDBA3726E97E65692E8273DA</li></ul></p>
# <h3>Malware Bazaar lookup:</h3>
# ...
