# %% [markdown]
# ## Import the template

# %%
import pe_sample

# %% [markdown]
# ## Configure the scan

# %%
from secret import VIRUSTOTAL_API_KEY

cfg = pe_sample.ScanConfig

cfg.virustotal_api_key = VIRUSTOTAL_API_KEY
cfg.procmon_vm = 'Windows10 VM'

# %% [markdown]
# ## Scan a sample

# %%
pe_sample.scan('37ea273266aa2d28430194fca27849170d609d338abc9c6c43c4e6be1bcf51f9.zip', cfg)
# Out:
# <h1>Report for 37ea273266aa2d28430194fca27849170d609d338abc9c6c43c4e6be1bcf51f9:</h1>
# <h3>Checksums:</h3>
# <p><ul><li><b>md5</b> - b315c590c3ad691604597ea41f8dd84e</li><li><b>sha1</b> - 6d15e7f0bb54df5b27a093f20186773ab0af7707</li><li><b>sha256</b> - 37ea273266aa2d28430194fca27849170d609d338abc9c6c43c4e6be1bcf51f9</li><li><b>imphash</b> - 365100121d9e63d60fff044587bff9a5</li><li><b>spamsum</b> - 24576:kKWhaK/j3uHJ3iekCUWCWbJxVjMJ4fNgGxFR24d7:LWhJjw9fkCUW9l0JO7xn24d</li><li><b>tlsh</b> - T150052323EA004447E615EC36FB55D7B61C10BD02BAE46A646EC5FCE770BD6A03B64A0F</li></ul></p>
# <h3>Malware Bazaar lookup:</h3>
# <p><ul><li>No sample with this sha256 found</li><li>No samples with matching imphash found</li><li>No samples with matching tlsh found</li></ul></p>
# <h3>56 malware engines detected a threat:</h3>
#         <p>
#             <details>
#                 <summary>
#                     Click here to show all 56
#                 </summary>
#                 <ul>
# ...
